# %% [markdown]
# A cooking website sells cooking equipment. They want to improve their product page. The product page has a rail with media (images or videos). Up until now, they have had a horizontal rail, a UX designer suggested having a vertical one. As a data analyst in the company, you suggested doing an AB test. You now have the results of the test and need to advise the company on whether they should ship the feature (vertical media rail) or not.

# %% [markdown]
# What is the business problem you are trying to solve?

# %% [markdown]
# Why does it matter to the company?

# %% [markdown]
# What are the benefits and drawbacks of the new variant in your opinion?

# %% [markdown]
# What is the hypothesis you are trying to test? What is the null hypothesis, what is the alternative hypothesis?

# %% [markdown]
# Why is an AB test a good method for testing the hypothesis?

# %% [markdown]
# Propose another method that could have been used and compare pros and cons of an AB test vs this method.

# %% [markdown]
# What metrics did you select in the AB test, and why? What is the primary metric? Are there other metrics you wished you had?

# %% [markdown]
# How do the distribution of your metrics compare between the two variants? Show me plots comparing the distributions.

# %% [markdown]
# What test did you apply? How did you specify your test and why (type of test, underlying distribution, parameters of the distribution, sample size, p-value…)

# %% [markdown]
# What is the result of the test?

# %% [markdown]
# What do you recommend the company to do?

# %% [markdown]
# Chat
#
# S8 Formulate and define a hypothesis for a research question:
#
# Business Problem: The business wants to improve the product page to enhance user experience and potentially increase sales by optimizing the display of media (images or videos) for cooking equipment.
#
# Importance to the Company: The product page is a critical touchpoint for customers in their purchasing journey. Enhancing this page can lead to better engagement, increased conversion rates, and ultimately higher revenue.
#
# Benefits and Drawbacks of the New Variant:
#
# Benefits:
# Vertical media rail might provide a better user experience by allowing users to scroll through media content more intuitively.
# It could potentially increase engagement with the media content, leading to more informed purchasing decisions.
# Drawbacks:
# Vertical layout may not fit well with the overall design of the product page.
# It could potentially push down other important elements on the page, reducing their visibility.
# Hypothesis:
#
# Null Hypothesis (H0): There is no significant difference in user engagement metrics between the horizontal and vertical media rails.
# Alternative Hypothesis (H1): User engagement metrics will be significantly different between the horizontal and vertical media rails.
# S9 Apply the most appropriate statistical technique to evaluate a hypothesis, using a data analysis tool:
#
# Why an AB Test is a Good Method:
#
# AB testing allows for a controlled experiment where users are randomly assigned to either the control group (horizontal media rail) or the experimental group (vertical media rail).
# It provides a straightforward way to measure the impact of the change by comparing key metrics between the two groups.
# Comparison with Another Method:
#
# Proposed Method: Multivariate testing, where multiple elements of the product page are changed simultaneously and their combined impact is measured.
# Pros and Cons of AB Test vs. Multivariate Testing:
# AB Test:
# Pros: Simple setup, clear interpretation of results, focused on a single change.
# Cons: Limited in assessing interactions between multiple changes, may not capture holistic impact.
# Multivariate Testing:
# Pros: Can assess combined impact of multiple changes, captures interactions between elements.
# Cons: Complex setup, potentially harder to interpret results, requires larger sample sizes.
# Metrics Selected in the AB Test:
#
# Metrics: Click-through rate (CTR), time spent on page, and conversion rate.
# Primary Metric: Conversion rate, as it directly measures the effectiveness of the product page in driving sales.
# Other Metrics: Bounce rate, engagement with media content.
# Comparison of Metric Distributions:
#
# Visualize distributions of metrics (CTR, time spent on page, conversion rate) between horizontal and vertical media rails using histograms or density plots.
# Test Applied:
#
# Independent samples t-test for comparing means between two groups.
# Specify test: Two-tailed test assuming unequal variances, significance level (alpha) set at 0.05.
# Result of the Test:
#
# Conduct the t-test for each metric (CTR, time spent on page, conversion rate).
# Determine if there is a statistically significant difference between the two groups for each metric.
# Analyze the effect size to understand the practical significance of the differences.
# Recommendation:
#
# If the test reveals a statistically significant improvement in the primary metric (conversion rate) with the vertical media rail, recommend implementing the change.
# Consider any practical implications, such as design compatibility and user feedback, before making the final decision.

# %% [markdown]
# a two sample test determines whether or not two populations parameters such as two means or two proportions are equal to each other.

# %% [markdown]
# 1. Why is an AB test a good method for testing the hypothesis?
# AB testing is a good method for testing hypotheses in situations where you want to compare two or more variants of a webpage or feature. It allows you to directly compare how different versions perform with statistical rigor.
#
# 2. Propose another method that could have been used and compare pros and cons of an AB test vs this method.
# Another method that could have been used is a before-and-after study, where you would compare the performance metrics before and after the change from horizontal to vertical media rail. However, this method might not account for external factors that could influence the results, such as seasonality or other changes to the website.
#
# Pros and Cons:
#
# AB Test:
#
# Pros: Directly compares performance between variants, controls for external factors through randomization, provides statistically significant results.
# Cons: Requires larger sample sizes, may take longer to conduct.
# Before-and-After Study:
#
# Pros: Easy to implement, does not require a large sample size.
# Cons: Susceptible to confounding variables, difficult to establish causality.
# 3. What metrics did you select in the AB test, and why? What is the primary metric? Are there other metrics you wished you had?
# Metrics selected for the AB test:
#
# Click-through rate (CTR) on the media.
# Number of add-to-cart events.
# The primary metric is likely the click-through rate on the media since it directly measures user engagement with the feature.
#
# Other metrics that could be useful:
#
# Conversion rate (from page view to add-to-cart).
# Time on page.
# 4. How do the distribution of your metrics compare between the two variants? Show me plots comparing the distributions.
# Let's plot histograms for the key metrics: click-through rate and number of add-to-cart events, comparing the two variants.

# %%
import matplotlib.pyplot as plt

# Plotting distribution of Clicks on media
plt.hist(data[data['Variant'] == 'Horizontal']['Clicks on media'], bins=10, alpha=0.5, label='Horizontal')
plt.hist(data[data['Variant'] == 'Vertical']['Clicks on media'], bins=10, alpha=0.5, label='Vertical')
plt.legend()
plt.title('Distribution of Clicks on media by Variant')
plt.xlabel('Clicks on media')
plt.ylabel('Frequency')
plt.show()

# Plotting distribution of Number of add to cart
plt.hist(data[data['Variant'] == 'Horizontal']['Number of add to cart'], bins=10, alpha=0.5, label='Horizontal')
plt.hist(data[data['Variant'] == 'Vertical']['Number of add to cart'], bins=10, alpha=0.5, label='Vertical')
plt.legend()
plt.title('Distribution of Number of add to cart by Variant')
plt.xlabel('Number of add to cart')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 5. What test did you apply? How did you specify your test and why (type of test, underlying distribution, parameters of the distribution, sample size, p-value…)?
# We'll apply a hypothesis test, such as a t-test or Mann-Whitney U test, to determine if there is a significant difference between the two variants.
#
# Given that we are dealing with click-through rates and counts of add-to-cart events, we may consider using a Mann-Whitney U test, which is non-parametric and does not assume normality.
#
# 6. What is the result of the test?
# Perform the test and determine the p-value to assess whether there is a significant difference between the two variants.

# %%
from scipy.stats import mannwhitneyu

# Perform Mann-Whitney U test for Clicks on media
statistic, p_value_clicks = mannwhitneyu(data[data['Variant'] == 'Horizontal']['Clicks on media'],
                                         data[data['Variant'] == 'Vertical']['Clicks on media'])

# Perform Mann-Whitney U test for Number of add to cart
statistic, p_value_add_to_cart = mannwhitneyu(data[data['Variant'] == 'Horizontal']['Number of add to cart'],
                                              data[data['Variant'] == 'Vertical']['Number of add to cart'])

print("p-value for Clicks on media:", p_value_clicks)
print("p-value for Number of add to cart:", p_value_add_to_cart)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 from scipy.stats import mannwhitneyu
#       3 # Perform Mann-Whitney U test for Clicks on media
# ----> 4 statistic, p_value_clicks = mannwhitneyu(data[data['Variant'] == 'Horizontal']['Clicks on media'],
#       5                                          data[data['Variant'] == 'Vertical']['Clicks on media'])
#       7 # Perform Mann-Whitney U test for Number of add to cart
#       8 statistic, p_value_add_to_cart = mannwhitneyu(data[data['Variant'] == 'Horizontal']['Number of add to cart'],
#       9                                               data[data['Variant'] == 'Vertical']['Number of add to cart'])
#
# ...

# %% [markdown]
# 7. What do you recommend the company to do?
# Based on the p-values obtained from the Mann-Whitney U test, if the p-value is less than the significance level (e.g., 0.05), we reject the null hypothesis, suggesting that there is a significant difference between the two variants.
#
# If the p-values are significant and positive, it suggests that the vertical media rail has a positive impact on user engagement (click-through rate) and/or conversion (add-to-cart events). In this case, it would be recommended to ship the feature.
#
# If the p-values are not significant, it indicates that there is no significant difference between the two variants, and further investigation or testing may be needed before making a decision.

# %% [markdown]
# Thank you for the clarification. Indeed, you're correct about the conditions under which the t-test can be applied, and the importance of the central limit theorem in ensuring the normality of the sampling distribution.
#
# Given that we have sufficiently large sample sizes and are dealing with sums (such as click-through rates) and proportions (such as add-to-cart rates), we can use the t-test for comparing means between the two variants. This allows us to leverage the central limit theorem to assume normality of the sampling distribution.
#
# Let's proceed with conducting a t-test to compare the means of click-through rates and add-to-cart rates between the two variants.

# %%
from scipy.stats import ttest_ind

# Perform t-test for Clicks on media
statistic_clicks, p_value_clicks = ttest_ind(data[data['Variant'] == 'Horizontal']['Clicks on media'],
                                             data[data['Variant'] == 'Vertical']['Clicks on media'])

# Perform t-test for Number of add to cart
statistic_add_to_cart, p_value_add_to_cart = ttest_ind(data[data['Variant'] == 'Horizontal']['Number of add to cart'],
                                                       data[data['Variant'] == 'Vertical']['Number of add to cart'])

print("p-value for Clicks on media (t-test):", p_value_clicks)
print("p-value for Number of add to cart (t-test):", p_value_add_to_cart)
# Out:
# p-value for Clicks on media (t-test): nan
# p-value for Number of add to cart (t-test): nan

# %% [markdown]
# Result of the test:
# Based on the p-values obtained from the t-tests, if the p-value is less than the significance level (e.g., 0.05), we reject the null hypothesis, suggesting that there is a significant difference between the two variants.
#
# Recommendation:
# If the p-values are significant and positive, it suggests that the vertical media rail has a positive impact on user engagement (click-through rate) and/or conversion (add-to-cart events). In this case, it would be recommended to ship the feature.
#
# If the p-values are not significant, it indicates that there is no significant difference between the two variants, and further investigation or testing may be needed before making a decision.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("assessment_da25.csv")

# %%
print(data.head())
# Out:
#   Variant  Number of page views  GMV (in $)  Number of add to cart  \
# 0       A                     5         0.0                      0
# 1       A                     4         0.0                      4
# 2       A                     4         0.0                      2
# 3       A                     5         0.0                      0
# 4       A                     5         0.0                      3
#
#    Clicks on media  Time on Page (sec)  user_id
# 0                2                  74        0
# 1                1                  21        1
# 2                0                   1        2
# 3                1                  26        3
# 4                3                  46        4

# %%
print(data.describe())
# Out:
#        Number of page views   GMV (in $)  Number of add to cart  \
# count           2000.000000  2000.000000            2000.000000
# mean               5.151000     8.489760               2.176500
# std                2.333864    27.861282               1.518387
# min                0.000000     0.000000               0.000000
# 25%                3.000000     0.000000               1.000000
# 50%                5.000000     0.000000               2.000000
# 75%                7.000000     0.000000               3.000000
# max               15.000000   152.610000              10.000000
#
#        Clicks on media  Time on Page (sec)      user_id
# count      2000.000000         2000.000000  2000.000000
# mean          1.409500           20.295000   999.500000
# std           1.208528           19.964676   577.494589
# min           0.000000            1.000000     0.000000
# 25%           1.000000            6.000000   499.750000
# ...

# %%
data.groupby('Variant')['Time on Page (sec)'].agg({'mean','std','count'})
# Out:
#            mean  count        std
# Variant
# A        20.543   1000  20.596076
# B        20.047   1000  19.319784

# %%
data.groupby('Variant')['Clicks on media'].agg({'mean','std','count'})
# Out:
#           mean  count       std
# Variant
# A        1.495   1000  1.230239
# B        1.324   1000  1.180855

# %%
data.groupby('Variant')['Number of page views'].agg({'mean','std','count'})
# Out:
#           mean  count       std
# Variant
# A        4.985   1000  2.236465
# B        5.317   1000  2.417096

# %%
data.groupby('Variant')['GMV (in $)'].agg({'mean','std','count'})
# Out:
#             mean  count        std
# Variant
# A        7.68999   1000  26.794816
# B        9.28953   1000  28.879687

# %%
data.groupby('Variant')['Number of add to cart'].agg({'mean','std','count'})
# Out:
#           mean  count       std
# Variant
# A        1.884   1000  1.297778
# B        2.469   1000  1.660662

# %%
sns.barplot(x=data['Variant'], y=data['GMV (in $)'], estimator=np.mean)
plt.title('GMV per Variant')
plt.xlabel('Variant')
plt.ylabel('GMV [$]')
# Out:
# Text(0, 0.5, 'GMV [$]')

# %% [markdown]
# H0: There is no difference in ad recall between sequenced ads and a repeated traditional ad.
#
# Ha: There is a difference in ad recall intent between sequenced ads and a repeated traditional ad.
#
# H0: There is no difference in purchase intent between sequenced ads and a repeated traditional ad.
#
# Ha: There is a difference in purchase intent between sequenced ads and a repeated traditional ad.
